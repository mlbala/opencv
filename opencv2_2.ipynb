# %%
# !git clone https://github.com/misbah4064/opencvTutorial.git
# %cd opencvTutorial/
# Out:
# Cloning into 'opencvTutorial'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 28 (delta 3), reused 12 (delta 1), pack-reused 0
# Unpacking objects: 100% (28/28), done.
# /content/opencvTutorial/opencvTutorial

# %% [markdown]
# # Part 2: Intermediate Exercises

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("images/shapes.png")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F023EB67290>

# %%
#convert RGB into HSV

hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2_imshow(hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F022F5EEFD0>

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower_blue = np.array([65,0,0])
upper_blue = np.array([110,255,255])
mask = cv2.inRange(hsv, lower_blue,upper_blue)
cv2_imshow(mask)
result = cv2.bitwise_and(image, image, mask = mask)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F022F5F82D0>
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F022F5F8290>

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#blue hue
lower_hue = np.array([65,0,0])
upper_hue = np.array([110,255,255])
mask = cv2.inRange(hsv, lower_hue,upper_hue)
result = cv2.bitwise_and(image, image, mask = mask)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F022F5EEC50>

# %%
#red color
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower_hue = np.array([0,0,0])
upper_hue = np.array([20,255,255])
mask = cv2.inRange(hsv, lower_hue,upper_hue)
result = cv2.bitwise_and(image, image, mask = mask)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F022F623CD0>

# %%
#Green color
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower_hue = np.array([46,0,0])
upper_hue = np.array([91,255,255])
mask = cv2.inRange(hsv, lower_hue,upper_hue)
result = cv2.bitwise_and(image, image, mask = mask)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F022F61BF10>

# %%
#Green color
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower_hue = np.array([0,0,0])
upper_hue = np.array([150,255,255])
mask = cv2.inRange(hsv, lower_hue,upper_hue)
result = cv2.bitwise_and(image, image, mask = mask)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F022F5EEC90>
